# %% [markdown]
# <a href="https://colab.research.google.com/github/plus2net/Python-basics/blob/main/openpyxl_3_worksheet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![alt text](https://www.plus2net.com/images/top2.jpg)        More on  [worksheet by openpyxl  ](https://www.plus2net.com/python/openpyxl-worksheet.php)

# %%
from openpyxl import Workbook

wb = Workbook()  # New workbook
ws = wb.active             # Default worksheet
ws.title = "Main"       # Rename default sheet

# Create additional sheets (appended at end by default)
wb.create_sheet("Summary")
wb.create_sheet("Data")

# Create a sheet at a specific position (index 0 = first)
wb.create_sheet("Intro", 0)

wb.save("openpyxl_sheets_demo.xlsx")

# %% [markdown]
# Get the list of worksheets

# %%
from openpyxl import load_workbook

wb = load_workbook("openpyxl_sheets_demo.xlsx")

# By name
ws_main = wb["Main"]

# By index (sheetnames returns a list of titles)
first_title = wb.sheetnames[0]
first_ws    = wb[first_title]

print("All sheets:", wb.sheetnames)
# Out:
# All sheets: ['Intro', 'Main', 'Summary', 'Data']

# %% [markdown]
# Rename the worksheet

# %%
# By name
ws_main = wb["Main"]

# By index (sheetnames returns a list of titles)
first_title = wb.sheetnames[0]
first_ws    = wb[first_title]

print("All sheets:", wb.sheetnames)
# Out:
# All sheets: ['Intro', 'Main', 'Summary', 'Data']

# %% [markdown]
# Rename a worksheet

# %%
# Change an existing sheet title
ws_ren = wb["Summary"]
ws_ren.title = "Overview"
print("All sheets:", wb.sheetnames)
wb.save("openpyxl_sheets_demo.xlsx")
# Out:
# All sheets: ['Overview', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %% [markdown]
# Move worksheet

# %%
# Move a sheet to the front
print("All sheets before move:", wb.sheetnames)
ws_data = wb["Data"]
wb.move_sheet(ws_data, -2)  # negative moves left, positive moves right
print("New order:", wb.sheetnames)
# Out:
# All sheets before move: ['Intro', 'Main', 'Overview', 'Data']
# New order: ['Intro', 'Data', 'Main', 'Overview']

# %% [markdown]
# Delete Worksheet

# %%
# Remove a worksheet (ensure it's not the only one)
print("Before delete  all sheets:", wb.sheetnames)
ws_intro = wb["Intro"]
wb.remove(ws_intro)

print("After delete:", wb.sheetnames)
wb.save("openpyxl_sheets_demo.xlsx")
# Out:
# Before delete  all sheets: ['Intro', 'Data', 'Main', 'Overview']
# After delete: ['Data', 'Main', 'Overview']

# %% [markdown]
# List all worksheets

# %%
for title in wb.sheetnames:
    print(title)
# Out:
# Data
# Main
# Overview

# %% [markdown]
# Monthly worksheet generator

# %%
from openpyxl import Workbook

months = ["Jan","Feb","Mar","Apr","May","Jun",
            "Jul","Aug","Sep","Oct","Nov","Dec"]

wb = Workbook()
wb.active.title = "Summary"

for m in months:
    ws = wb.create_sheet(m)
    # Optional: set a header row
    ws["A1"] = "Date"
    ws["B1"] = "Note"

wb.save("monthly_report.xlsx")

# %% [markdown]
# Copy worksheet

# %%
source = wb["Apr"]
dup    = wb.copy_worksheet(source)
dup.title = "Apr_Copy"
wb.save("monthly_report.xlsx")
