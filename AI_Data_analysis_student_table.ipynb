# %% [markdown]
# <a href="https://colab.research.google.com/github/plus2net/Python-basics/blob/main/AI_Data_analysis_student_table.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Download the student.xlsx the Excel file from plus2net.com

# %%
# !wget https://www.plus2net.com/python/download/student.xlsx
# Out:
# --2025-07-08 02:29:06--  https://www.plus2net.com/python/download/student.xlsx
# Resolving www.plus2net.com (www.plus2net.com)... 68.178.227.154
# Connecting to www.plus2net.com (www.plus2net.com)|68.178.227.154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10100 (9.9K) [application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]
# Saving to: ‘student.xlsx’
#
# student.xlsx        100%[===================>]   9.86K  --.-KB/s    in 0s
#
# 2025-07-08 02:29:07 (109 MB/s) - ‘student.xlsx’ saved [10100/10100]

# %% [markdown]
# Or Download the student.csv the CSV file from plus2net.com

# %%
# !wget !wget https://www.plus2net.com/python/download/student.csv
# Out:
# --2025-07-08 02:27:05--  http://!wget/
# Resolving !wget (!wget)... failed: Name or service not known.
# wget: unable to resolve host address ‘!wget’
# --2025-07-08 02:27:05--  https://www.plus2net.com/python/download/student.csv
# Resolving www.plus2net.com (www.plus2net.com)... 68.178.227.154
# Connecting to www.plus2net.com (www.plus2net.com)|68.178.227.154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 952 [text/csv]
# Saving to: ‘student.csv’
#
# student.csv         100%[===================>]     952  --.-KB/s    in 0s
#
# 2025-07-08 02:27:06 (225 MB/s) - ‘student.csv’ saved [952/952]
#
# FINISHED --2025-07-08 02:27:06--
# Total wall clock time: 0.7s
# Downloaded: 1 files, 952 in 0s (225 MB/s)

# %% [markdown]
# We can download sqlite database with student table.

# %%
# !wget https://www.plus2net.com/python/download/my_db.db
# Out:
# --2025-07-08 02:23:38--  https://www.plus2net.com/python/download/my_db.db
# Resolving www.plus2net.com (www.plus2net.com)... 68.178.227.154
# Connecting to www.plus2net.com (www.plus2net.com)|68.178.227.154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16384 (16K)
# Saving to: ‘my_db.db’
#
# my_db.db            100%[===================>]  16.00K  --.-KB/s    in 0s
#
# 2025-07-08 02:23:39 (136 MB/s) - ‘my_db.db’ saved [16384/16384]

# %%
import sqlite3
import pandas as pd

# Connect to the SQLite database
conn = sqlite3.connect('my_db.db')

# Create a cursor object
cursor = conn.cursor()

# Execute a query to find students whose names end with A or B
query = "SELECT * FROM student WHERE name LIKE '%A' OR name LIKE '%B'"
cursor.execute(query)

# Fetch the results
filtered_students = cursor.fetchall()

# Get column names
column_names = [description[0] for description in cursor.description]

# Convert the result to a pandas DataFrame for better display
if filtered_students:
    df = pd.DataFrame(filtered_students, columns=column_names)
    display(df)
else:
    print("No students found matching the criteria.")

# Close the connection
conn.close()
# Out:
#    id         name  class  mark gender
# 0   7  My John Rob   Five    78   male
# 1  26       Crelea  Seven    79   male

# %%
import sqlite3

# Connect to the SQLite database
conn = sqlite3.connect('my_db.db')

# Create a cursor object
cursor = conn.cursor()

# Execute a query to get the names of all tables in the database
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")

# Fetch all table names
tables = cursor.fetchall()

# Print the table names
print("Tables in the database:")
for table in tables:
    print(table[0])

# Close the connection
conn.close()
# Out:
# Tables in the database:
# category
# subcategory
# student

# %%
import pandas as pd

# Read the CSV file into a pandas DataFrame
try:
    df_csv = pd.read_csv('student.csv')

    # Filter the DataFrame to find students whose IDs are even numbers
    filtered_students_csv = df_csv[df_csv['id'] % 2 == 0]

    # Display the filtered DataFrame
    if not filtered_students_csv.empty:
        display(filtered_students_csv)
    else:
        print("No students with even IDs found in the CSV file.")

except FileNotFoundError:
    print("Error: 'student.csv' not found. Please make sure the file is downloaded.")
except KeyError:
    print("Error: 'id' column not found in the CSV file. Please check the column names.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
#     id        name  class  mark  gender
# 1    2    Max Ruin  Three    85    male
# 3    4  Krish Star   Four    60  female
# 5    6   Alex John   Four    55    male
# 7    8      Asruid   Five    85    male
# 9   10    Big John   Four    55  female
# 11  12       Recky    Six    94  female
# 13  14        Bigy  Seven    88  female
# 15  16       Gimmy   Four    88    male
# 17  18       Honny   Five    75    male
# 19  20      Jackly   Nine    65  female
# 21  22      Reggid  Seven    55  female
# 23  24   Tiddy Now  Seven    78    male
# 25  26      Crelea  Seven    79    male
# 27  28   Rojj Base  Seven    86  female
# 29  30   Reppy Red    Six    79  female
# 31  32   Binn Rott  Seven    90  female
# 33  34    Gain Toe  Seven    69    male

# %%
import pandas as pd

# Read the Excel file into a pandas DataFrame
try:
    df_excel = pd.read_excel('student.xlsx')

    # Filter the DataFrame to find students whose IDs are even numbers
    filtered_students_excel = df_excel[df_excel['id'] % 2 == 0]

    # Display the filtered DataFrame
    if not filtered_students_excel.empty:
        display(filtered_students_excel)
    else:
        print("No students with even IDs found in the Excel file.")

except FileNotFoundError:
    print("Error: 'student.xlsx' not found. Please make sure the file is downloaded.")
except KeyError:
    print("Error: 'id' column not found in the Excel file. Please check the column names.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
#     id        name  class  mark  gender
# 1    2    Max Ruin  Three    85    male
# 3    4  Krish Star   Four    60  female
# 5    6   Alex John   Four    55    male
# 7    8      Asruid   Five    85    male
# 9   10    Big John   Four    55  female
# 11  12       Recky    Six    94  female
# 13  14        Bigy  Seven    88  female
# 15  16       Gimmy   Four    88    male
# 17  18       Honny   Five    75    male
# 19  20      Jackly   Nine    65  female
# 21  22      Reggid  Seven    55  female
# 23  24   Tiddy Now  Seven    78    male
# 25  26      Crelea  Seven    79    male
# 27  28   Rojj Base  Seven    86  female
# 29  30   Reppy Red    Six    79  female
# 31  32   Binn Rott  Seven    90  female
# 33  34    Gain Toe  Seven    69    male
